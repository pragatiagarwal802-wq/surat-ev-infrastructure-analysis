# %% [markdown]
# <a href="https://colab.research.google.com/github/pragatiagarwal802-wq/surat-ev-infrastructure-analysis/blob/main/api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import output
import uvicorn

# 1. This creates a public-facing URL for your Colab port
# Click the link this prints AFTER you run the uvicorn cell below
print(f"Your API Link: {output.serve_kernel_port_as_window(8000)}")

# 2. Run the server (this will stay 'running' and that's okay!)
if __name__ == "__main__":
    config = uvicorn.Config(app=app, host="0.0.0.0", port=8000, log_level="info")
    server = uvicorn.Server(config)
    await server.serve()
# Out:
# ...
# Try `serve_kernel_port_as_iframe` instead.
# Your API Link: None
# INFO:     Started server process [4205]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:47330 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:47346 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:48270 - "GET /docs HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48278 - "GET /openapi.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44638 - "GET /get-score/8942d98a64bffff HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [4205]
